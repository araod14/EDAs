# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tiktok_df=pd.read_csv('TikTok_songs_2022.csv')

# %%
tiktok_df.shape
# Out:
# (263, 18)

# %%
tiktok_df.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0  Running Up That Hill (A Deal With God)      Kate Bush          81
# 1                               As It Was   Harry Styles          91
# 2                                 Sunroof    Nicky Youre          73
# 3                              Heat Waves  Glass Animals          80
# 4                         About Damn Time          Lizzo          81
#
#                         album  track_pop  danceability  energy  loudness  \
# 0              Hounds Of Love         95         0.629   0.547   -13.123
# 1                   As It Was         96         0.520   0.731    -5.338
# 2                     Sunroof         44         0.768   0.716    -5.110
# 3  Dreamland (+ Bonus Levels)         89         0.761   0.525    -6.900
# 4             About Damn Time         92         0.836   0.743    -6.305
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# Descripcion de las columnas

# %% [raw]
# track_name   "Nombre de la cancion"
# artist_name  "Nombre del artista"
# artist_pop   "nivel pop del artista"
# albun        "Albun al ue pertenece la cancion"
# track_pop    "nivel pop de la cancion"
# danceability "nivel de bailabilidad"
# energy       "nivel de energia de la cancion"
# loudness     "NIvel del volumen de la cancion"
# mode         "modo de la cancion" OJO
# key          "llave de la cancion" OJO
# speechiness  "NIvel de vocabilidad de la cancion"
# acousticness "Nivel de acusticos de la cancion"
# liveness     "NIvel interpretacion en vivo de la cancion"
# valence      "BAlance de la cancion" OJO
# tempo        "Tempo"
# time_signature "Tiempo asignado"
# duration_ms  "duracion en ms"

# %%
tiktok_df.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  263.000000  263.000000    263.000000  263.000000  263.000000
# mean    64.186312   59.844106      0.715338    0.682631   -6.300513
# std     18.146338   24.976524      0.117722    0.141756    1.905114
# min     18.000000    0.000000      0.308000    0.214000  -13.468000
# 25%     50.000000   47.000000      0.646000    0.593000   -7.423500
# 50%     64.000000   66.000000      0.726000    0.701000   -6.067000
# 75%     81.000000   79.500000      0.796500    0.790500   -4.887000
# max     95.000000   97.000000      0.961000    0.955000   -2.634000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  263.000000  263.000000   263.000000    263.000000        263.000000
# mean     0.536122    5.809886     0.117268      0.193188          0.020244
# std      0.499644    3.657312     0.101417      0.214588          0.109370
# ...

# %%
tiktok_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        263 non-null    object
#  1   artist_name       263 non-null    object
#  2   artist_pop        263 non-null    int64
#  3   album             263 non-null    object
#  4   track_pop         263 non-null    int64
#  5   danceability      263 non-null    float64
#  6   energy            263 non-null    float64
#  7   loudness          263 non-null    float64
#  8   mode              263 non-null    int64
#  9   key               263 non-null    int64
#  10  speechiness       263 non-null    float64
#  11  acousticness      263 non-null    float64
#  12  instrumentalness  263 non-null    float64
#  13  liveness          263 non-null    float64
#  14  valence           263 non-null    float64
#  15  tempo             263 non-null    float64
# ...

# %%
tiktok_df.corr()
# Out:
#                   artist_pop  track_pop  danceability    energy  loudness  \
# artist_pop          1.000000   0.528718      0.025500 -0.182508  0.121257
# track_pop           0.528718   1.000000     -0.069720 -0.043791  0.095679
# danceability        0.025500  -0.069720      1.000000 -0.119912  0.108099
# energy             -0.182508  -0.043791     -0.119912  1.000000  0.585077
# loudness            0.121257   0.095679      0.108099  0.585077  1.000000
# mode                0.003254   0.002747     -0.033789 -0.072749 -0.049226
# key                -0.031555  -0.154423      0.077736  0.103403  0.087612
# speechiness        -0.044713  -0.075914      0.194117 -0.102667 -0.088429
# acousticness        0.061327   0.031077     -0.012272 -0.459485 -0.388096
# instrumentalness   -0.072859  -0.064372     -0.068245  0.102296 -0.054539
# liveness           -0.197161  -0.127429     -0.161132  0.136489  0.070948
# valence             0.163149   0.106094      0.370981  0.048231  0.171599
# ...

# %%
sns.heatmap(tiktok_df.corr())
# Out:
# <AxesSubplot:>

# %% [raw]
# Las canciones con mayor "loudness" tienen mayor "energy" y las que tienen mayor "valence" son mas "danceables", se debe investigar que significa musicalmente el "valence"

# %%
plt.hist(tiktok_df['energy'])
# Out:
# (array([ 1.,  5., 10., 19., 24., 41., 61., 48., 39., 15.]),
#  array([0.214 , 0.2881, 0.3622, 0.4363, 0.5104, 0.5845, 0.6586, 0.7327,
#         0.8068, 0.8809, 0.955 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.pairplot(tiktok_df)

# %%
fig, (ax1, ax2)=plt.subplots(nrows=1, ncols=2)
ax1.scatter(tiktok_df["loudness"], tiktok_df["energy"])
ax2.scatter(tiktok_df["valence"], tiktok_df["danceability"])

# %% [raw]
# -Debido a los gaficos anteriores se decarte relacion valence-danceability.
# -Si se mantiene la corelacion loudness-energy

# %%
tiktok_df[tiktok_df.energy == tiktok_df.energy.max()]
# Out:
#      track_name artist_name  artist_pop       album  track_pop  danceability  \
# 207  Boss Bitch    Doja Cat          88  Boss Bitch         78         0.707
#
#      energy  loudness  mode  key  speechiness  acousticness  instrumentalness  \
# 207   0.955    -4.593     0   10        0.222         0.127               0.0
#
#      liveness  valence    tempo  time_signature  duration_ms
# 207     0.202    0.575  125.989               4       134240

# %%
tiktok_df.sort_values("danceability" , ascending=False).head(10)
# Out:
#                           track_name          artist_name  artist_pop  \
# 199    Don't Rush (feat. Headie One)     Young T & Bugsey          60
# 209                           Tap In             Saweetie          73
# 115                        Thot Shit  Megan Thee Stallion          82
# 136     Bundles (feat. Taylor Girlz)         Kayla Nicole          54
# 169  WAP (feat. Megan Thee Stallion)              Cardi B          81
# 198                            Renee                SALES          61
# 228                     WHATS POPPIN          Jack Harlow          84
# 102                          Buss It          Erica Banks          54
# 68                              Lost          Frank Ocean          82
# 243                         Skechers           DripReport          54
#
#                                album  track_pop  danceability  energy  \
# 199    Don't Rush (feat. Headie One)         63         0.961   0.461
# ...

# %%
tiktok_df.sort_values("loudness" , ascending=False).head(10)
# Out:
#                                             track_name          artist_name  \
# 216                                         Astronomia             Vicetone
# 137                                    Sweater Weather    The Neighbourhood
# 259                                         Dandelions              Ruth B.
# 45         1, 2, 3 (feat. Jason Derulo & De La Ghetto)          Sofía Reyes
# 105                                  Beauty And A Beat               Glamii
# 13                                Being Good Is Boring            Jena Rose
# 124  Wellerman - Sea Shanty / 220 KID x Billen Ted ...         Nathan Evans
# 147  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...                Riton
# 115                                          Thot Shit  Megan Thee Stallion
# 214                                     Break My Heart             Dua Lipa
#
#      artist_pop                                              album  track_pop  \
# ...

# %%
tiktok_df.artist_name.value_counts().sort_values(ascending=False).head(12)
# Out:
# Doja Cat          8
# Coopex            6
# Dame Dame         5
# Lil Nas X         4
# Farux             4
# Alex Alexander    4
# YES YES           4
# Alex D'Rosso      3
# The Kid LAROI     3
# Ariana Grande     3
# Astelle           3
# Pop Smoke         3
# Name: artist_name, dtype: int64
